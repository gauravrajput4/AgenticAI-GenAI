# %%
import logging

# %%
# create a logger for module1
logger1=logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

# create a logger for module2
logger2=logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

# Basic configuration for logging
logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S"
)

# %%
# log messages using logger1
logger1.debug("debug message for module 1")

logger2.warning("warning message for module 2")
logger2.error("error message for module 2")
# Out:
# 2026-07-25 14:59:15 - module1 - DEBUG - debug message for module 1
# 2026-07-25 14:59:15 - module2 - WARNING - warning message for module 2
# 2026-07-25 14:59:15 - module2 - ERROR - error message for module 2
