# %% [markdown]
# #### Embedding Techniques
# Converting text into Vectors

# %%
import os
from dotenv import load_dotenv


load_dotenv() # Load all the environment variables
# Out:
# python-dotenv could not parse statement starting at line 3
# True

# %%
os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings
embeddings=OpenAIEmbeddings(model="text-embedding-3-large")
embeddings
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x110531e50>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x110531250>, model='text-embedding-3-large', dimensions=None, deployment='text-embedding-ada-002', openai_api_version=None, openai_api_base=None, openai_api_type=None, openai_proxy=None, embedding_ctx_length=8191, openai_api_key=SecretStr('**********'), openai_organization=None, allowed_special=None, disallowed_special=None, chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, http_async_client=None, check_embedding_ctx_length=True)

# %%
text="This is a tutorial on OPENAI embedding"
query_result=embeddings.embed_query(text)
query_result
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[36], line 2
#       1 text="This is a tutorial on OPENAI embedding"
# ----> 2 query_result=embeddings.embed_query(text)
#       3 query_result
#
# File ~/WorkSpace/Agentic AI and Gen AI/.venv/lib/python3.13/site-packages/langchain_openai/embeddings/base.py:805, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     795 """Call out to OpenAI's embedding endpoint for embedding query text.
#     796
#     797 Args:
#    (...)    802     Embedding for the text.
#     803 """
#     804 self._ensure_sync_client_available()
# --> 805 return self.embed_documents([text], **kwargs)[0]
#
# File ~/WorkSpace/Agentic AI and Gen AI/.venv/lib/python3.13/site-packages/langchain_openai/embeddings/base.py:755, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     752 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     753 # This could be optimized to avoid double work when all texts are short enough.
#     754 engine = cast(str, self.deployment)
# --> 755 return self._get_len_safe_embeddings(
#     756     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     757 )
#
# File ~/WorkSpace/Agentic AI and Gen AI/.venv/lib/python3.13/site-packages/langchain_openai/embeddings/base.py:622, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     620 # Make API call with this batch
#     621 batch_tokens = tokens[i:batch_end]
# --> 622 response = self.client.create(input=batch_tokens, **client_kwargs)
#     623 if not isinstance(response, dict):
#     624     response = response.model_dump()
#
# File ~/WorkSpace/Agentic AI and Gen AI/.venv/lib/python3.13/site-packages/openai/resources/embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145         security={"bearer_auth": True},
#     146     ),
#     147     cast_to=CreateEmbeddingResponse,
#     148 )
#
# File ~/WorkSpace/Agentic AI and Gen AI/.venv/lib/python3.13/site-packages/openai/_base_client.py:1360, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1351     warnings.warn(
#    1352         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1353         "Please pass raw bytes via the `content` parameter instead.",
#    1354         DeprecationWarning,
#    1355         stacklevel=2,
#    1356     )
#    1357 opts = FinalRequestOptions.construct(
#    1358     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1359 )
# -> 1360 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/WorkSpace/Agentic AI and Gen AI/.venv/lib/python3.13/site-packages/openai/_base_client.py:1133, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1130             err.response.read()
#    1132         log.debug("Re-raising status error")
# -> 1133         raise self._make_status_error_from_response(err.response) from None
#    1135     break
#    1137 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************lsAA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}

# %%
len(query_result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 len(query_result)
#
# NameError: name 'query_result' is not defined

# %%
embeddings_1024=OpenAIEmbeddings(model="text-embedding-3-small",dimensions=1024)

# %%
embeddings_1024
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x110678c00>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x110679370>, model='text-embedding-3-small', dimensions=1024, deployment='text-embedding-ada-002', openai_api_version=None, openai_api_base=None, openai_api_type=None, openai_proxy=None, embedding_ctx_length=8191, openai_api_key=SecretStr('**********'), openai_organization=None, allowed_special=None, disallowed_special=None, chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, http_async_client=None, check_embedding_ctx_length=True)

# %%
from langchain_community.document_loaders import TextLoader

loader=TextLoader('../Speech.txt')
docs=loader.load()


from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter=RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=50
)

final_doc=text_splitter.split_documents(docs)
final_doc
# Out:
# [Document(metadata={'source': '../Speech.txt'}, page_content='My parents impressed on me the value of that you work hard for what you want in life. That your word'),
#  Document(metadata={'source': '../Speech.txt'}, page_content='hard for what you want in life. That your word is your bond and you do what you say and keep your'),
#  Document(metadata={'source': '../Speech.txt'}, page_content='your bond and you do what you say and keep your promise. That you treat people with respect. Show'),
#  Document(metadata={'source': '../Speech.txt'}, page_content='promise. That you treat people with respect. Show the values and morals in in the daily life. That'),
#  Document(metadata={'source': '../Speech.txt'}, page_content='the values and morals in in the daily life. That is the lesson that we continue to pass on to our'),
#  Document(metadata={'source': '../Speech.txt'}, page_content='is the lesson that we continue to pass on to our son.'),
#  Document(metadata={'source': '../Speech.txt'}, page_content='We need to pass those lessons on to the many generations to follow. [Cheering] Because we want our'),
#  Document(metadata={'source': '../Speech.txt'}, page_content='to follow. [Cheering] Because we want our children in these nations to know that the only limit to'),
#  Document(metadata={'source': '../Speech.txt'}, page_content='in these nations to know that the only limit to your achievement is the strength of your dreams and'),
#  Document(metadata={'source': '../Speech.txt'}, page_content='achievement is the strength of your dreams and your willingness to work for them.')]

# %%
## Vector Embedding anf Vector storeDB
from langchain_community.vectorstores import Chroma

db=Chroma.from_documents(final_doc,embeddings_1024)
db
# Out:
# python-dotenv could not parse statement starting at line 3
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[41], line 4
#       1 ## Vector Embedding anf Vector storeDB
#       2 from langchain_community.vectorstores import Chroma
#       3
# ----> 4 db=Chroma.from_documents(final_doc,embeddings_1024)
#       5 db
#
# File ~/WorkSpace/Agentic AI and Gen AI/.venv/lib/python3.13/site-packages/langchain_community/vectorstores/chroma.py:887, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     885 texts = [doc.page_content for doc in documents]
#     886 metadatas = [doc.metadata for doc in documents]
# --> 887 return cls.from_texts(
#     888     texts=texts,
#     889     embedding=embedding,
#     890     metadatas=metadatas,
#     891     ids=ids,
#     892     collection_name=collection_name,
#     893     persist_directory=persist_directory,
#     894     client_settings=client_settings,
#     895     client=client,
#     896     collection_metadata=collection_metadata,
#     897     **kwargs,
#     898 )
#
# File ~/WorkSpace/Agentic AI and Gen AI/.venv/lib/python3.13/site-packages/langchain_community/vectorstores/chroma.py:843, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     835     from chromadb.utils.batch_utils import create_batches
#     837     for batch in create_batches(
#     838         api=chroma_collection._client,
#     839         ids=ids,
#     840         metadatas=metadatas,
#     841         documents=texts,
#     842     ):
# --> 843         chroma_collection.add_texts(
#     844             texts=batch[3] if batch[3] else [],
#     845             metadatas=batch[2] if batch[2] else None,
#     846             ids=batch[0],
#     847         )
#     848 else:
#     849     chroma_collection.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#
# File ~/WorkSpace/Agentic AI and Gen AI/.venv/lib/python3.13/site-packages/langchain_community/vectorstores/chroma.py:277, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     275 texts = list(texts)
#     276 if self._embedding_function is not None:
# --> 277     embeddings = self._embedding_function.embed_documents(texts)
#     278 if metadatas:
#     279     # fill metadatas with empty dicts if somebody
#     280     # did not specify metadata for all texts
#     281     length_diff = len(texts) - len(metadatas)
#
# File ~/WorkSpace/Agentic AI and Gen AI/.venv/lib/python3.13/site-packages/langchain_openai/embeddings/base.py:755, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     752 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     753 # This could be optimized to avoid double work when all texts are short enough.
#     754 engine = cast(str, self.deployment)
# --> 755 return self._get_len_safe_embeddings(
#     756     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     757 )
#
# File ~/WorkSpace/Agentic AI and Gen AI/.venv/lib/python3.13/site-packages/langchain_openai/embeddings/base.py:622, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     620 # Make API call with this batch
#     621 batch_tokens = tokens[i:batch_end]
# --> 622 response = self.client.create(input=batch_tokens, **client_kwargs)
#     623 if not isinstance(response, dict):
#     624     response = response.model_dump()
#
# File ~/WorkSpace/Agentic AI and Gen AI/.venv/lib/python3.13/site-packages/openai/resources/embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145         security={"bearer_auth": True},
#     146     ),
#     147     cast_to=CreateEmbeddingResponse,
#     148 )
#
# File ~/WorkSpace/Agentic AI and Gen AI/.venv/lib/python3.13/site-packages/openai/_base_client.py:1360, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1351     warnings.warn(
#    1352         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1353         "Please pass raw bytes via the `content` parameter instead.",
#    1354         DeprecationWarning,
#    1355         stacklevel=2,
#    1356     )
#    1357 opts = FinalRequestOptions.construct(
#    1358     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1359 )
# -> 1360 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/WorkSpace/Agentic AI and Gen AI/.venv/lib/python3.13/site-packages/openai/_base_client.py:1133, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1130             err.response.read()
#    1132         log.debug("Re-raising status error")
# -> 1133         raise self._make_status_error_from_response(err.response) from None
#    1135     break
#    1137 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************lsAA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}

# %%
query="What is the speech about?"
retrieved_results=db.similarity_search(query)
print(retrieved_results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 query="What is the speech about?"
# ----> 2 retrieved_results=db.similarity_search(query)
#       3 print(retrieved_results)
#
# NameError: name 'db' is not defined
