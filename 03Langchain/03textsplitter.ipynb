# %% [markdown]
# ### Text Splitting from documents - RecursiveCharacterTextSplitter
#
# This text splitter is the recommended one for genric text. It is parameterized by a list of characters. It tries to split on them in order until the chunks are small enough. The default list is ["\n\n","\n"," ",""]. This has the effect of trying to keep all paragraph (and then sentences, and then words) together as long as possible, as those would generically seem to be the strongest semantically related pieces of text.
# * How the text is split: by the list of characters.
# * How the chunks size is measured: by number of characters.

# %%
from  langchain_community.document_loaders import PyPDFLoader

loader=PyPDFLoader('resume.pdf').load()
loader

# %% [markdown]
# ### How to recursively split text by characters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter=RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=50
)

final_doc=text_splitter.split_documents(loader)
final_doc

# %%
print(final_doc[0])

# %%
print(final_doc[1])

# %%
from langchain_community.document_loaders import TextLoader

loader=TextLoader('Speech.txt')
loader

# %% [markdown]
# ### How to split by character- character text splitter
# This is the simplest method. This splits based on a given character sequencem which defaults to "\n\n". chunk length is measured by number of characters.
# * How the text is split: by the single character separator.
# * How the chunk size is measured: by the number of characters.

# %%
speech=""
with open('Speech.txt') as f:
    speech=f.read()



text_splitter=RecursiveCharacterTextSplitter(
    chunk_size=100,
    chunk_overlap=40
)
text=text_splitter.create_documents([speech])

# %%
print(text[0])

# %%
print(text[1])
